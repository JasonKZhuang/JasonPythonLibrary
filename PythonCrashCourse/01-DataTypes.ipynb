# %%
1
# Out:
# 1

# %%
123.456
# Out:
# 123.456

# %%
1+1
# Out:
# 2

# %%
2*3
# Out:
# 6

# %%
1/2
# Out:
# 0.5

# %%
 # 2 power 4
2 ** 4
# Out:
# 16

# %%
(2+3) * (4+5)
# Out:
# 45

# %%
10%2
# Out:
# 0

# %%
10%3
# Out:
# 1

# %%
5%2
# Out:
# 1

# %%
# variable assigment
var = 2
var
# Out:
# 2

# %%
x=2
y=3
z = x*y
z
# Out:
# 6

# %%
z + 4
# Out:
# 10

# %%
# String

# %%
' single quote'
# Out:
# ' single quote'

# %%
"Double quote"
# Out:
# "Double 's quote"

# %%
"Double quote's output"
# Out:
# "Double quote's output"

# %%
print(z)
# Out:
# 6

# %%
num = 12
name = 'Jason'

# %%
'My number is {} and my name is {}'.format(num, name)
# Out:
# 'My number is 12 and my name is Jason'

# %%
'My number is {one} and my name is {two}'.format(one=num, two=name)
# Out:
# 'My number is 12 and my name is Jason'
